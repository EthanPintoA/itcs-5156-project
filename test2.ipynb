# %%
from fastai.vision.all import *

# %%
rzs = Resize(128, method='squish')

# %%
path = 'animals/cat/0b54dde5f5.jpg'

# %%
# convert path to a tensorimage

img = PILImage.create(path)

img?
# Out:
# Type:        PILImage
# String form: PILImage mode=RGB size=1071x1600
# File:        c:\...\anaconda3\current\app\lib\site-packages\fastai\vision\core.py
# Docstring:   A RGB Pillow `Image` that can show itself and converts to `TensorImage`

# %%
new_img = rzs(img)

new_img?

new_img.show()
# Out:
# <Axes: >
# Type:        PILImage
# String form: PILImage mode=RGB size=128x128
# File:        c:\...\apps\anaconda3\current\app\lib\site-packages\fastai\vision\core.py
# Docstring:   A RGB Pillow `Image` that can show itself and converts to `TensorImage`
